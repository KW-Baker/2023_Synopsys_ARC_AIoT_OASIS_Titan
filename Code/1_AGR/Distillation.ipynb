# %% [markdown]
# # <font color = purple> 2023 Synopsys ARC AIoT Design Contest - Knowledge Distillation </font>

# %% [markdown]
# # Knowledge Distillation & Model Fractionation

# %%
import os
import glob
import time
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Activation, Softmax, ReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Layer, Flatten, Dense, Dropout, add
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-07-04 18:25:22.143116: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
# !nvidia-smi
# Out:
# Tue Jul  4 18:25:23 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 31%   29C    P8     9W / 250W |      7MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:82:00.0 Off |                  N/A |
# | 35%   42C    P8     9W / 250W |      7MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:83:00.0 Off |                  N/A |
# | 31%   43C    P8    11W / 300W |      6MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

for gpu in gpus:
    print(gpu)
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# 2023-07-04 18:25:23.339623: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-07-04 18:25:23.464336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-07-04 18:25:23.464821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-04 18:25:23.465268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:82:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-04 18:25:23.465341: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-07-04 18:25:23.474913: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-07-04 18:25:23.475006: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-07-04 18:25:23.507632: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-07-04 18:25:23.508000: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-07-04 18:25:23.508949: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-07-04 18:25:23.510035: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-07-04 18:25:23.510249: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-07-04 18:25:23.511793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2

# %% [markdown]
# ## <font color = navy> Configurations </font>

# %%
class Config():
    # Data path
    IMAGE_DIR = "./train_img"
    LABEL_DIR = "./train_label/label.csv"
    
    # Degree unit
    DEG_UNIT = 6
    
    #  Dataloader parameters
    SPLIT = 0.2
    
    # Batch size
    BATCH_SIZE = 6 #16 #8
    
    # Image size
    IMG_HEIGHT = 224 #224
    IMG_WIDTH = 224 #224
    
    # Model parameters
    NUM_CLASSES = int(360 / DEG_UNIT)
    IN_CHANNEL = 1
    INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, IN_CHANNEL)
    
    # Learning parameters
    lr = 1e-3
    num_epochs = 30 # 20 #30
    teacher_loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    student_loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    distill_loss_func = keras.losses.KLDivergence()
    loss_func = "categorical_crossentropy"
    
    # Optimizer parameters
    opt = 'adam'
    
    # Distiller parameters
    alpha = 0.1      # weight to student_loss_fn and 1-alpha to distill_loss_func
    temperature = 3  # Temperature for softening probability distributions. Larger temperature gives softer distributions.
    
    # Model
    NUM_STAGE = 4
    model_names = ['MobileNetV2-base', 'MobileNetV2-small', 'MobileNetV2-tiny', 'MobileNetV2-micro']
    model_archs = ['base', 'small', 'tiny', 'micro']
    models = [None] * NUM_STAGE
    trainableParams = [None] * NUM_STAGE
    nonTrainableParams = [None] * NUM_STAGE
    totalParams = [None] * NUM_STAGE

# %% [markdown]
# ## <font color = navy> Load and Preprocess Dataset </font>

# %%
def load_data(img_path, lab_path, split=0.2):
    img_files = sorted(glob.glob(img_path + "/*"), key=os.path.getmtime) # Sort by time
    lab_df = pd.read_csv(lab_path)['class'].to_numpy() # Read label from csv
    data_x = []
    data_y = []
    
    # Concatenate images & labels
    for idx, img_file in enumerate(img_files):
        # image
        img = Image.open(img_file)
        img = img.convert('L') # Convert to gray
        img = np.array(img, dtype=int)
        img = img - 128.0 # Normalize
        
        # label
        lab = np.array(lab_df[idx], dtype=int)
        lab = np.expand_dims(lab, axis=0)
        
        data_x.append(img)
        data_y.append(lab)
    
    # Train & test split
    X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=split, random_state=42, shuffle=True)
    
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    return X_train, X_test, y_train, y_test

# %%
# Loading the dataset
X_train, X_test, y_train, y_test = load_data(Config.IMAGE_DIR, Config.LABEL_DIR)

# %% [markdown]
# ## <font color = navy> Show Data </font>

# %%
fig = plt.figure(figsize=(15,10))
for i in range(15):  
    ax = fig.add_subplot(3, 5, i+1)
    img = Image.fromarray(np.uint8(X_train[i] + 128)) # *255
    img = img.convert('RGBA')
    
    ax.imshow(img, cmap=plt.get_cmap('gray'))
    lab = np.squeeze(y_train[i])
    lower = lab * Config.DEG_UNIT
    upper = (lab+1) * Config.DEG_UNIT
    ax.set_title('degree: {y1}~{y2}'.format(y1=lower, y2=upper))
    plt.axis('off')

# %% [markdown]
# ## <font color = navy> One-hot encoding </font>

# %%
# y_train = to_categorical(y_train, Config.NUM_CLASSES)
# y_test = to_categorical(y_test, Config.NUM_CLASSES)

# %%
print("y_train: \n", y_train)
print("\n")
print("y_test: \n", y_test)
# Out:
# y_train:
#  [[19]
#  [ 0]
#  [36]
#  ...
#  [ 9]
#  [10]
#  [17]]
#
#
# y_test:
#  [[43]
#  [49]
#  [46]
#  ...
#  [42]
#  [33]
#  [12]]

# %% [markdown]
# ## <font color = navy> Reshape Images </font>

# %%
# Reshape
X_train = X_train.reshape(-1, Config.IMG_HEIGHT, Config.IMG_WIDTH, 1)
X_test = X_test.reshape(-1, Config.IMG_HEIGHT, Config.IMG_WIDTH, 1)

# %% [markdown]
# ## <font color = navy> Build Models </font>

# %% [markdown]
# ### <font color = red> Build Model: MobileNetV2 </font>

# %%
def expansion_block(x, t, filters, block_id):
    prefix = 'block_{}_'.format(block_id)
    total_filter = t*filters
    x = Conv2D(total_filter, 1, padding='same',use_bias=False, name=prefix+'expand')(x)
    x = BatchNormalization(name=prefix+'expand_bn')(x)
    x = ReLU(6, name=prefix+'expand_relu')(x) # ReLU 6
    
    return x

def depthwise_block(x, stride, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = DepthwiseConv2D(3, strides=(stride,stride), padding='same', use_bias=False, name=prefix +'depthwise_conv')(x)
    x = BatchNormalization(name=prefix+'dw_bn')(x)
    x = ReLU(6,name=prefix+'dw_relu')(x)
    
    return x

def projection_block(x, out_channels, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = Conv2D(filters=out_channels, kernel_size=1, padding='same', use_bias=False, name=prefix+'compress')(x)
    x = BatchNormalization(name=prefix+'compress_bn')(x)
    
    return x

# %%
def Bottleneck(x, t, filters, out_channels, stride, block_id):
    y = expansion_block(x, t, filters, block_id)
    y = depthwise_block(y, stride, block_id)
    y = projection_block(y, out_channels, block_id)
    
    if y.shape[-1]==x.shape[-1]:
        y = add([x,y])
    return y

# %%
def MobileNetV2(input_image=Config.INPUT_SHAPE, n_classes=Config.NUM_CLASSES, arch='base'):
    if arch == 'base':
        input = Input(input_image)

        x = Conv2D(32,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=16,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 320, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 1280, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'small':
        input = Input(input_image)

        x = Conv2D(16,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=8,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 48, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 640, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'tiny':
        input = Input(input_image)

        x = Conv2D(8,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=4,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 6, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 6, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 16, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 80, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 320, kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model
    
    
    elif arch == 'micro':
        input = Input(input_image)

        x = Conv2D(4,kernel_size=3,strides=(2,2),padding = 'same', use_bias=False)(input)
        x = BatchNormalization(name='conv1_bn')(x)
        x = ReLU(6, name = 'conv1_relu')(x)

        # 17 Bottlenecks

        x = depthwise_block(x,stride=1,block_id=1)
        x = projection_block(x, out_channels=4,block_id=1)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 3, stride = 2,block_id = 2)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 3, stride = 1,block_id = 3)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 2,block_id = 4)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 1,block_id = 5)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 4, stride = 1,block_id = 6)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 2,block_id = 7)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 8)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 9)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 8, stride = 1,block_id = 10)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 11)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 12)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 12, stride = 1,block_id = 13)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 2,block_id = 14)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 1,block_id = 15)
        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 20, stride = 1,block_id = 16)

        x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 40, stride = 1,block_id = 17)


        #1*1 conv
        x = Conv2D(filters = 160 , kernel_size = 1, padding='same', use_bias=False, name = 'last_conv')(x)
        x = BatchNormalization(name='last_bn')(x)
        x = ReLU(6,name='last_relu')(x)

        #AvgPool 7*7
        x = GlobalAveragePooling2D(name='global_average_pool')(x)

        output = Dense(n_classes, activation='softmax')(x)

        model = Model(input, output)

        return model

# %%
for i in range(Config.NUM_STAGE):
    print('[' + Config.model_names[i] + ']')
    Config.models[i] = MobileNetV2(arch=Config.model_archs[i])
    Config.trainableParams[i] = np.sum([np.prod(v.get_shape()) for v in Config.models[i].trainable_weights])
    Config.nonTrainableParams[i] = np.sum([np.prod(v.get_shape()) for v in Config.models[i].non_trainable_weights])
    Config.totalParams[i] = Config.trainableParams[i] + Config.nonTrainableParams[i]
    print('Trainable Prameters: ', Config.trainableParams[i])
    print('Non-trainable Parameters: ', Config.nonTrainableParams[i])
    print('Total Parameters: ', Config.totalParams[i])
    # Config.models[i].summary()
    print('-------------------------------------------------')
# Out:
# [MobileNetV2-base]
# 2023-07-04 18:25:38.192322: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-04 18:25:38.917468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-07-04 18:25:38.917833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-04 18:25:38.918165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:82:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2023-07-04 18:25:38.920003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2
# 2023-07-04 18:25:38.920110: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-07-04 18:25:39.899988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-07-04 18:25:39.900028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2023-07-04 18:25:39.900036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2023-07-04 18:25:39.900041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2023-07-04 18:25:39.900045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2023-07-04 18:25:39.901938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9644 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:83:00.0, compute capability: 7.5)
# 2023-07-04 18:25:39.902719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10405 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2023-07-04 18:25:39.903329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10405 MB memory) -> physical GPU (device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:82:00.0, compute capability: 6.1)
# Trainable Prameters:  2300156
# Non-trainable Parameters:  34112
# Total Parameters:  2334268
# -------------------------------------------------
# [MobileNetV2-small]
# Trainable Prameters:  618940
# Non-trainable Parameters:  17056
# Total Parameters:  635996
# -------------------------------------------------
# [MobileNetV2-tiny]
# Trainable Prameters:  176708
# Non-trainable Parameters:  8528
# Total Parameters:  185236
# -------------------------------------------------
# [MobileNetV2-micro]
# Trainable Prameters:  55462
# Non-trainable Parameters:  4316
# Total Parameters:  59778
# -------------------------------------------------

# %% [markdown]
# ## <font color = navy> Distiller </font>

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super().__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# ## <font color = navy> Create Teacher Model </font>

# %%
teacher = Config.models[0]

# %%
teacher.compile(
    optimizer=Config.opt,
    loss=Config.teacher_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

# %% [markdown]
# ## <font color = navy> Create Student Model </font>

# %%
student = Config.models[1]

# %%
student.compile(
    optimizer=Config.opt,
    loss=Config.teacher_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

# %% [markdown]
# ## <font color = navy> Save & Load for Copy Student Model </font>

# %%
student.save('student')
student = keras.models.load_model("student")
copy_student = keras.models.load_model("student")
# Out:
# 2023-07-04 18:25:50.490340: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /home/bakerchen/.conda/envs/2023ARC/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: student/assets

# %%
# Clone student for later comparison
student_scratch = copy_student

# %% [markdown]
# ## <font color = navy> Train Teacher Model </font>

# %%
# Train and evaluate teacher on data.
teacher_history = teacher.fit(X_train, y_train,
                              validation_split=0.2,
                              batch_size=Config.BATCH_SIZE,
                              verbose=1,
                              epochs=Config.num_epochs)
# Out:
# 2023-07-04 18:26:14.440522: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-07-04 18:26:14.458830: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1999990000 Hz
# Epoch 1/30
# /home/bakerchen/.conda/envs/2023ARC/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4929: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   warnings.warn(
# 2023-07-04 18:26:17.817878: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-07-04 18:26:18.759055: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8700
# 2023-07-04 18:26:19.405013: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-04 18:26:19.405069: W tensorflow/stream_executor/gpu/asm_compiler.cc:56] Couldn't invoke ptxas --version
# 2023-07-04 18:26:19.406203: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-04 18:26:19.406287: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-07-04 18:26:19.415273: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-07-04 18:26:19.415596: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 1067/1067 [==============================] - 84s 73ms/step - loss: 3.3018 - sparse_categorical_accuracy: 0.0916 - val_loss: 2.5698 - val_sparse_categorical_accuracy: 0.1462
# Epoch 2/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 2.1555 - sparse_categorical_accuracy: 0.2102 - val_loss: 2.4782 - val_sparse_categorical_accuracy: 0.1869
# Epoch 3/30
# 1067/1067 [==============================] - 78s 73ms/step - loss: 1.7833 - sparse_categorical_accuracy: 0.2945 - val_loss: 1.6227 - val_sparse_categorical_accuracy: 0.3431
# Epoch 4/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 1.3877 - sparse_categorical_accuracy: 0.4383 - val_loss: 0.9112 - val_sparse_categorical_accuracy: 0.6275
# Epoch 5/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.9337 - sparse_categorical_accuracy: 0.6236 - val_loss: 0.7164 - val_sparse_categorical_accuracy: 0.6787
# Epoch 6/30
# 1067/1067 [==============================] - 77s 73ms/step - loss: 0.7818 - sparse_categorical_accuracy: 0.6700 - val_loss: 0.5184 - val_sparse_categorical_accuracy: 0.7781
# Epoch 7/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.6817 - sparse_categorical_accuracy: 0.7144 - val_loss: 0.5861 - val_sparse_categorical_accuracy: 0.7481
# Epoch 8/30
# 1067/1067 [==============================] - 77s 73ms/step - loss: 0.6309 - sparse_categorical_accuracy: 0.7342 - val_loss: 0.5637 - val_sparse_categorical_accuracy: 0.7706
# Epoch 9/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.5978 - sparse_categorical_accuracy: 0.7469 - val_loss: 0.4903 - val_sparse_categorical_accuracy: 0.7894
# Epoch 10/30
# 1067/1067 [==============================] - 78s 73ms/step - loss: 0.5524 - sparse_categorical_accuracy: 0.7725 - val_loss: 0.4946 - val_sparse_categorical_accuracy: 0.7881
# Epoch 11/30
# 1067/1067 [==============================] - 77s 73ms/step - loss: 0.5128 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.4504 - val_sparse_categorical_accuracy: 0.8056
# Epoch 12/30
# 1067/1067 [==============================] - 79s 74ms/step - loss: 0.4660 - sparse_categorical_accuracy: 0.8112 - val_loss: 0.4898 - val_sparse_categorical_accuracy: 0.7869
# Epoch 13/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.4405 - sparse_categorical_accuracy: 0.8173 - val_loss: 0.4763 - val_sparse_categorical_accuracy: 0.8069
# Epoch 14/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.4180 - sparse_categorical_accuracy: 0.8328 - val_loss: 0.4629 - val_sparse_categorical_accuracy: 0.8056
# Epoch 15/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.3857 - sparse_categorical_accuracy: 0.8469 - val_loss: 0.4556 - val_sparse_categorical_accuracy: 0.8144
# Epoch 16/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.3633 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3812 - val_sparse_categorical_accuracy: 0.8219
# Epoch 17/30
# 1067/1067 [==============================] - 73s 69ms/step - loss: 0.3553 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.4230 - val_sparse_categorical_accuracy: 0.8300
# Epoch 18/30
# 1067/1067 [==============================] - 74s 69ms/step - loss: 0.3254 - sparse_categorical_accuracy: 0.8703 - val_loss: 0.4665 - val_sparse_categorical_accuracy: 0.8138
# Epoch 19/30
# 1067/1067 [==============================] - 74s 69ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.4063 - val_sparse_categorical_accuracy: 0.8356
# Epoch 20/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.2995 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.4113 - val_sparse_categorical_accuracy: 0.8294
# Epoch 21/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.2827 - sparse_categorical_accuracy: 0.8881 - val_loss: 0.3843 - val_sparse_categorical_accuracy: 0.8444
# Epoch 22/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8600
# Epoch 23/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.2464 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.3817 - val_sparse_categorical_accuracy: 0.8413
# Epoch 24/30
# 1067/1067 [==============================] - 79s 74ms/step - loss: 0.2227 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8675
# Epoch 25/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.2168 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8594
# Epoch 26/30
# 1067/1067 [==============================] - 75s 70ms/step - loss: 0.2082 - sparse_categorical_accuracy: 0.9208 - val_loss: 0.3988 - val_sparse_categorical_accuracy: 0.8356
# Epoch 27/30
# 1067/1067 [==============================] - 76s 71ms/step - loss: 0.1919 - sparse_categorical_accuracy: 0.9272 - val_loss: 0.4306 - val_sparse_categorical_accuracy: 0.8250
# Epoch 28/30
# 1067/1067 [==============================] - 78s 73ms/step - loss: 0.1807 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.3583 - val_sparse_categorical_accuracy: 0.8625
# Epoch 29/30
# 1067/1067 [==============================] - 77s 72ms/step - loss: 0.1928 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8650
# Epoch 30/30
# 1067/1067 [==============================] - 76s 72ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.3841 - val_sparse_categorical_accuracy: 0.8587

# %% [markdown]
# ### <font color = red> Evaluation: Teacher Model </font>

# %%
teacher_score = teacher.evaluate(X_test, y_test, verbose=0)
print(teacher_score)
# Out:
# [0.342197060585022, 0.8725000023841858]

# %% [markdown]
# ## <font color = navy> Distill Teacher to Student </font>

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(
    optimizer=Config.opt,
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=Config.student_loss_func,
    distillation_loss_fn=Config.distill_loss_func,
    alpha=Config.alpha,
    temperature=Config.temperature,
)

# %%
# Distill teacher to student
distiller_history = distiller.fit(
    X_train, y_train,
    validation_split=0.2,
    batch_size=Config.BATCH_SIZE,
    verbose=1,
    epochs=Config.num_epochs)
# Out:
# Epoch 1/30
# 1067/1067 [==============================] - 91s 80ms/step - sparse_categorical_accuracy: 0.0834 - student_loss: 3.4707 - distillation_loss: 0.0091 - val_sparse_categorical_accuracy: 0.1456 - val_student_loss: 1.8876
# Epoch 2/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.2298 - student_loss: 2.1081 - distillation_loss: 0.0080 - val_sparse_categorical_accuracy: 0.3344 - val_student_loss: 1.6116
# Epoch 3/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.4630 - student_loss: 1.3990 - distillation_loss: 0.0062 - val_sparse_categorical_accuracy: 0.5575 - val_student_loss: 0.7667
# Epoch 4/30
# 1067/1067 [==============================] - 86s 80ms/step - sparse_categorical_accuracy: 0.5745 - student_loss: 1.0155 - distillation_loss: 0.0050 - val_sparse_categorical_accuracy: 0.5906 - val_student_loss: 0.3114
# Epoch 5/30
# 1067/1067 [==============================] - 86s 81ms/step - sparse_categorical_accuracy: 0.6391 - student_loss: 0.8623 - distillation_loss: 0.0043 - val_sparse_categorical_accuracy: 0.6488 - val_student_loss: 1.2932
# Epoch 6/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.6716 - student_loss: 0.7842 - distillation_loss: 0.0040 - val_sparse_categorical_accuracy: 0.6456 - val_student_loss: 1.0356
# Epoch 7/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.7002 - student_loss: 0.7067 - distillation_loss: 0.0037 - val_sparse_categorical_accuracy: 0.7831 - val_student_loss: 0.1574
# Epoch 8/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.7386 - student_loss: 0.6412 - distillation_loss: 0.0033 - val_sparse_categorical_accuracy: 0.7306 - val_student_loss: 0.3406
# Epoch 9/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.7473 - student_loss: 0.6067 - distillation_loss: 0.0032 - val_sparse_categorical_accuracy: 0.7319 - val_student_loss: 0.2353
# Epoch 10/30
# 1067/1067 [==============================] - 85s 80ms/step - sparse_categorical_accuracy: 0.7731 - student_loss: 0.5617 - distillation_loss: 0.0029 - val_sparse_categorical_accuracy: 0.7100 - val_student_loss: 0.5751
# Epoch 11/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.7833 - student_loss: 0.5263 - distillation_loss: 0.0027 - val_sparse_categorical_accuracy: 0.8012 - val_student_loss: 0.1714
# Epoch 12/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8009 - student_loss: 0.5032 - distillation_loss: 0.0026 - val_sparse_categorical_accuracy: 0.7850 - val_student_loss: 0.2486
# Epoch 13/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8127 - student_loss: 0.4651 - distillation_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7581 - val_student_loss: 0.1382
# Epoch 14/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8250 - student_loss: 0.4457 - distillation_loss: 0.0023 - val_sparse_categorical_accuracy: 0.8181 - val_student_loss: 0.5295
# Epoch 15/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8386 - student_loss: 0.4068 - distillation_loss: 0.0021 - val_sparse_categorical_accuracy: 0.8106 - val_student_loss: 0.3785
# Epoch 16/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8481 - student_loss: 0.3879 - distillation_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7444 - val_student_loss: 0.6007
# Epoch 17/30
# 1067/1067 [==============================] - 85s 80ms/step - sparse_categorical_accuracy: 0.8542 - student_loss: 0.3718 - distillation_loss: 0.0020 - val_sparse_categorical_accuracy: 0.8244 - val_student_loss: 0.3250
# Epoch 18/30
# 1067/1067 [==============================] - 85s 80ms/step - sparse_categorical_accuracy: 0.8616 - student_loss: 0.3515 - distillation_loss: 0.0019 - val_sparse_categorical_accuracy: 0.8338 - val_student_loss: 0.0426
# Epoch 19/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8714 - student_loss: 0.3301 - distillation_loss: 0.0018 - val_sparse_categorical_accuracy: 0.8325 - val_student_loss: 0.2433
# Epoch 20/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8767 - student_loss: 0.3166 - distillation_loss: 0.0017 - val_sparse_categorical_accuracy: 0.8462 - val_student_loss: 0.2845
# Epoch 21/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.8941 - student_loss: 0.2874 - distillation_loss: 0.0016 - val_sparse_categorical_accuracy: 0.8331 - val_student_loss: 0.0423
# Epoch 22/30
# 1067/1067 [==============================] - 87s 81ms/step - sparse_categorical_accuracy: 0.8972 - student_loss: 0.2754 - distillation_loss: 0.0015 - val_sparse_categorical_accuracy: 0.8350 - val_student_loss: 0.0486
# Epoch 23/30
# 1067/1067 [==============================] - 84s 78ms/step - sparse_categorical_accuracy: 0.8961 - student_loss: 0.2596 - distillation_loss: 0.0015 - val_sparse_categorical_accuracy: 0.8112 - val_student_loss: 0.2558
# Epoch 24/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.9050 - student_loss: 0.2496 - distillation_loss: 0.0014 - val_sparse_categorical_accuracy: 0.7994 - val_student_loss: 0.3305
# Epoch 25/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.9106 - student_loss: 0.2402 - distillation_loss: 0.0014 - val_sparse_categorical_accuracy: 0.8294 - val_student_loss: 0.4010
# Epoch 26/30
# 1067/1067 [==============================] - 83s 78ms/step - sparse_categorical_accuracy: 0.9172 - student_loss: 0.2192 - distillation_loss: 0.0013 - val_sparse_categorical_accuracy: 0.8356 - val_student_loss: 0.2267
# Epoch 27/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.9289 - student_loss: 0.1999 - distillation_loss: 0.0012 - val_sparse_categorical_accuracy: 0.8587 - val_student_loss: 0.4020
# Epoch 28/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.9186 - student_loss: 0.2070 - distillation_loss: 0.0013 - val_sparse_categorical_accuracy: 0.8331 - val_student_loss: 0.4042
# Epoch 29/30
# 1067/1067 [==============================] - 84s 79ms/step - sparse_categorical_accuracy: 0.9331 - student_loss: 0.1884 - distillation_loss: 0.0012 - val_sparse_categorical_accuracy: 0.8450 - val_student_loss: 0.0452
# Epoch 30/30
# 1067/1067 [==============================] - 86s 81ms/step - sparse_categorical_accuracy: 0.9308 - student_loss: 0.1841 - distillation_loss: 0.0012 - val_sparse_categorical_accuracy: 0.8131 - val_student_loss: 1.0570

# %% [markdown]
# ### <font color = red> Evaluation: Distiller Student Model </font>

# %%
# Evaluate student on test dataset
distiller_score = distiller.evaluate(X_test, y_test, verbose=0)
print(distiller_score)
# Out:
# [0.8374999761581421, 0.673521101474762]

# %%
student_score = student.evaluate(X_test, y_test, verbose=0)
print(student_score)
# Out:
# [0.48540422320365906, 0.8374999761581421]

# %% [markdown]
# ## <font color = navy> Train Original Student Model </font>

# %%
# Train student as doen usually
student_scratch.compile(
    optimizer=keras.optimizers.Adam(),
    loss=Config.student_loss_func,
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

# %%
# Train and evaluate student trained from scratch.
student_scratch_history = student_scratch.fit(
    X_train, y_train,
    validation_split=0.2,
    batch_size=Config.BATCH_SIZE,
    verbose=1,
    epochs=Config.num_epochs)
# Out:
# Epoch 1/30
# 1067/1067 [==============================] - 68s 60ms/step - loss: 3.9903 - sparse_categorical_accuracy: 0.0359 - val_loss: 3.4433 - val_sparse_categorical_accuracy: 0.0569
# Epoch 2/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 2.4468 - sparse_categorical_accuracy: 0.1720 - val_loss: 1.7890 - val_sparse_categorical_accuracy: 0.2719
# Epoch 3/30
# 1067/1067 [==============================] - 63s 60ms/step - loss: 1.7994 - sparse_categorical_accuracy: 0.3155 - val_loss: 1.2271 - val_sparse_categorical_accuracy: 0.5031
# Epoch 4/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 1.1591 - sparse_categorical_accuracy: 0.5305 - val_loss: 0.9698 - val_sparse_categorical_accuracy: 0.5981
# Epoch 5/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.9498 - sparse_categorical_accuracy: 0.6112 - val_loss: 0.7821 - val_sparse_categorical_accuracy: 0.6700
# Epoch 6/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6681 - val_loss: 0.5317 - val_sparse_categorical_accuracy: 0.7825
# Epoch 7/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.7373 - sparse_categorical_accuracy: 0.6853 - val_loss: 0.6935 - val_sparse_categorical_accuracy: 0.6925
# Epoch 8/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.6774 - sparse_categorical_accuracy: 0.7148 - val_loss: 0.6419 - val_sparse_categorical_accuracy: 0.7344
# Epoch 9/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.6305 - sparse_categorical_accuracy: 0.7430 - val_loss: 0.5501 - val_sparse_categorical_accuracy: 0.7675
# Epoch 10/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.5981 - sparse_categorical_accuracy: 0.7614 - val_loss: 0.4852 - val_sparse_categorical_accuracy: 0.7987
# Epoch 11/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.5480 - sparse_categorical_accuracy: 0.7756 - val_loss: 0.4218 - val_sparse_categorical_accuracy: 0.8231
# Epoch 12/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.5135 - sparse_categorical_accuracy: 0.7886 - val_loss: 0.4650 - val_sparse_categorical_accuracy: 0.7981
# Epoch 13/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.4626 - sparse_categorical_accuracy: 0.8181 - val_loss: 0.4770 - val_sparse_categorical_accuracy: 0.8019
# Epoch 14/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.4575 - sparse_categorical_accuracy: 0.8131 - val_loss: 0.4459 - val_sparse_categorical_accuracy: 0.8138
# Epoch 15/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.4285 - sparse_categorical_accuracy: 0.8338 - val_loss: 0.5834 - val_sparse_categorical_accuracy: 0.7750
# Epoch 16/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.4003 - sparse_categorical_accuracy: 0.8453 - val_loss: 0.5235 - val_sparse_categorical_accuracy: 0.7875
# Epoch 17/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.3814 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.3646 - val_sparse_categorical_accuracy: 0.8413
# Epoch 18/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.3623 - sparse_categorical_accuracy: 0.8552 - val_loss: 0.4605 - val_sparse_categorical_accuracy: 0.8175
# Epoch 19/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.3094 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.4014 - val_sparse_categorical_accuracy: 0.8462
# Epoch 20/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.3239 - sparse_categorical_accuracy: 0.8745 - val_loss: 0.3918 - val_sparse_categorical_accuracy: 0.8363
# Epoch 21/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.2964 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.4851 - val_sparse_categorical_accuracy: 0.8281
# Epoch 22/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.2830 - sparse_categorical_accuracy: 0.8923 - val_loss: 0.4568 - val_sparse_categorical_accuracy: 0.8275
# Epoch 23/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.2644 - sparse_categorical_accuracy: 0.8986 - val_loss: 0.3948 - val_sparse_categorical_accuracy: 0.8506
# Epoch 24/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.9011 - val_loss: 0.4757 - val_sparse_categorical_accuracy: 0.8175
# Epoch 25/30
# 1067/1067 [==============================] - 64s 60ms/step - loss: 0.2356 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.4058 - val_sparse_categorical_accuracy: 0.8431
# Epoch 26/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.2140 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3747 - val_sparse_categorical_accuracy: 0.8550
# Epoch 27/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.2168 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.4421 - val_sparse_categorical_accuracy: 0.8388
# Epoch 28/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.4600 - val_sparse_categorical_accuracy: 0.8250
# Epoch 29/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.1881 - sparse_categorical_accuracy: 0.9316 - val_loss: 0.3972 - val_sparse_categorical_accuracy: 0.8475
# Epoch 30/30
# 1067/1067 [==============================] - 63s 59ms/step - loss: 0.1898 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.4631 - val_sparse_categorical_accuracy: 0.8300

# %% [markdown]
# ### <font color = red> Evaluation: Original Student Model </font>

# %%
student_scratch_score = student_scratch.evaluate(X_test, y_test, verbose=0)
print(student_scratch_score)
# Out:
# [0.3889411985874176, 0.8529999852180481]

# %% [markdown]
# ## <font color = navy> Save & Load Teacher model </font>

# %%
teacher.save('teacher')

# %%
teacher = keras.models.load_model("teacher")

# %% [markdown]
# ## <font color = navy> Proposed Method: Model Fractionation </font>

# %%
# def fractionizer(models, stages):
#     for i in range(len(models)):
#         print('Stage ', i)
